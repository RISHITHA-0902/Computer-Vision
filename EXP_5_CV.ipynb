# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read original color image
img = cv2.imread("image1.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Create a 5x5 kernel
kernel = np.ones((5, 5), np.uint8)

# Apply erosion
eroded = cv2.erode(gray, kernel, iterations=1)

# Convert eroded image to BGR
eroded_bgr = cv2.cvtColor(eroded, cv2.COLOR_GRAY2BGR)

# Combine images side by side
combined = np.hstack((img, eroded_bgr))

# Display using cv2_imshow
cv2_imshow(combined)

# Save output
cv2.imwrite("eroded_image.jpg", combined)

# cv2.waitKey(0) # Not needed with cv2_imshow in Colab
# cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
# Out:
# <PIL.Image.Image image mode=RGB size=1010x330>
# True
