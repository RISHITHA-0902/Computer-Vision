# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread("image1.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Canny Edge Detection
edges = cv2.Canny(gray, 100, 200)

# Convert edges to BGR (3 channels)
edges_bgr = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

# Resize output to match original image size
edges_bgr = cv2.resize(edges_bgr, (img.shape[1], img.shape[0]))

# Combine images side by side
combined = np.hstack((img, edges_bgr))

# Display
cv2_imshow(combined)

# Save output
cv2.imwrite("canny_edges.jpg", combined)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1010x330>
