# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread("image1.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert grayscale to BGR (required for horizontal stacking)
gray_bgr = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

# Resize both images to the same size
gray_bgr = cv2.resize(gray_bgr, (img.shape[1], img.shape[0]))

# Combine images side by side
combined = np.hstack((img, gray_bgr))

# Display combined image
cv2_imshow(combined)

# Save combined output
cv2.imwrite("gray_image.jpg", combined)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1010x330>
